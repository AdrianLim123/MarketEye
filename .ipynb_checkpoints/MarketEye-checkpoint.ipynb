# %% [markdown]
# # MarketEye

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels
import pmdarima
from statsmodels.tsa.arima.model import ARIMA
from pmdarima.arima.utils import ndiffs
import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning

# %% [markdown]
# ### Load CSV data into training and test dataframes

# %%
csv_location = "./data/MarketEye Data - ALL_Average.csv"
df = pd.read_csv(csv_location)
df
# Out:
#     WeekNum  Cabbage  Carrot  Baguio Beans  Patatas  Pechay Baguio  Chayote  \
# 0         1    115.0   120.0         140.0    80.00          70.00     40.0
# 1         2    104.0   120.0         120.0    80.00          62.00     40.0
# 2         3     92.5   140.0          85.0    77.50          60.00     40.0
# 3         4     86.0   153.0          80.0    78.00          60.00     40.0
# 4         5     80.0   120.0          80.0    75.00          60.00     40.0
# 5         6     70.0    96.0          80.0    76.00          59.00     40.0
# 6         7     80.0    84.0          80.0    75.00          64.00     40.0
# 7         8     80.0    97.5          80.0    77.50          61.25     45.0
# 8         9     80.0   100.0          80.0    80.00          60.00     50.0
# 9        10     80.0    97.5          90.0    80.00          60.00     50.0
# 10       11     80.0    80.0          80.0    75.00          61.00     46.0
# 11       12     70.0    70.0          76.0    74.00          54.00     50.0
# 12       13     68.0    80.0          78.0    66.00          60.00     50.0
# 13       14     68.0    78.0          80.0    75.00          59.00     40.0
# 14       15     64.0    79.0          80.0    62.00          56.00     40.0
# 15       16     62.5    90.0          80.0    60.00          52.50     40.0
# 16       17     60.0    98.0          80.0    60.00          54.00     39.0
# 17       18     60.0   100.0          92.0    62.00          58.00     40.0
# 18       19     60.0   106.0         100.0    64.00          60.00     40.0
# 19       20     60.0   104.0          82.0    66.00          58.00     40.0
# 20       21     60.0    92.0          80.0    60.00          58.00     40.0
# 21       22     62.5    90.0          80.0    60.00          60.00     40.0
# 22       23     72.0    84.0          80.0    62.00          66.00     40.0
# 23       24     75.0    80.0          80.0    68.33          70.00     40.0
# 24       25     79.0    91.0          80.0    76.00          74.00     37.0
# 25       26     77.0    84.0          76.0    68.00          70.00     34.0
# 26       27     81.0    80.0          80.0    68.00          70.00     34.0
# 27       28     80.0    85.0          80.0    75.00          72.50     35.0
# 28       29     80.0    80.0          79.0    74.00          72.00     36.0
# 29       30     72.0    82.0         108.0    76.00          64.00     35.0
#
#     Ampalaya  Sitao  Pechay Tagalog  Squash  Eggplant  Tomato
# 0       80.0   70.0           62.50   40.00    100.00   60.00
# 1       74.0   76.0           60.00   40.00     80.00   60.00
# 2       65.0   77.5           60.00   40.00     60.00   60.00
# 3       60.0   74.0           58.00   40.00     62.00   60.00
# 4       80.0   86.0           60.00   40.00     68.00   60.00
# 5       96.0  100.0           62.00   38.00     91.00   59.00
# 6      100.0  100.0           66.00   38.00    100.00   51.00
# 7       90.0  100.0           66.25   35.00    100.00   60.00
# 8       80.0   94.0           72.00   36.00     78.00   60.00
# 9       95.0  120.0           80.00   40.00     80.00   60.00
# 10     120.0  116.0           70.00   39.00     80.00   60.00
# 11     116.0  112.0           64.00   38.00     80.00   60.00
# 12      92.0   98.0           57.00   40.00     66.00   60.00
# 13      90.0   95.0           59.00   40.00     64.00   60.00
# 14     112.0  100.0           57.00   38.00     60.00   57.00
# 15     100.0   87.5           56.25   37.50     62.50   60.00
# 16     100.0   80.0           60.00   40.00     70.00   60.00
# 17     100.0   80.0           60.00   40.00     72.00   60.00
# 18     116.0   80.0           60.00   40.00     72.00   80.00
# 19     104.0   80.0           58.00   40.00     70.00   80.00
# 20     100.0   80.0           60.00   46.00     59.00   80.00
# 21      95.0   77.5           67.50   50.00     55.00   80.00
# 22      93.0   70.0           68.00   50.00     60.00  100.00
# 23     100.0   80.0           70.00   53.33     76.67  113.33
# 24     100.0   80.0           70.00   50.00     78.00  128.00
# 25     100.0   76.0           62.00   50.00     68.00   98.00
# 26      98.0   73.0           60.00   50.00     72.00   88.00
# 27     100.0   77.5           60.00   45.00     67.50   97.50
# 28      98.0   79.0           58.00   40.00     62.00   98.00
# 29     100.0  112.0           60.00   40.00     60.00   91.00

# %%
training = df.iloc[:26]
test     = df.iloc[26:]

# %%
training
# Out:
#     WeekNum  Cabbage  Carrot  Baguio Beans  Patatas  Pechay Baguio  Chayote  \
# 0         1    115.0   120.0         140.0    80.00          70.00     40.0
# 1         2    104.0   120.0         120.0    80.00          62.00     40.0
# 2         3     92.5   140.0          85.0    77.50          60.00     40.0
# 3         4     86.0   153.0          80.0    78.00          60.00     40.0
# 4         5     80.0   120.0          80.0    75.00          60.00     40.0
# 5         6     70.0    96.0          80.0    76.00          59.00     40.0
# 6         7     80.0    84.0          80.0    75.00          64.00     40.0
# 7         8     80.0    97.5          80.0    77.50          61.25     45.0
# 8         9     80.0   100.0          80.0    80.00          60.00     50.0
# 9        10     80.0    97.5          90.0    80.00          60.00     50.0
# 10       11     80.0    80.0          80.0    75.00          61.00     46.0
# 11       12     70.0    70.0          76.0    74.00          54.00     50.0
# 12       13     68.0    80.0          78.0    66.00          60.00     50.0
# 13       14     68.0    78.0          80.0    75.00          59.00     40.0
# 14       15     64.0    79.0          80.0    62.00          56.00     40.0
# 15       16     62.5    90.0          80.0    60.00          52.50     40.0
# 16       17     60.0    98.0          80.0    60.00          54.00     39.0
# 17       18     60.0   100.0          92.0    62.00          58.00     40.0
# 18       19     60.0   106.0         100.0    64.00          60.00     40.0
# 19       20     60.0   104.0          82.0    66.00          58.00     40.0
# 20       21     60.0    92.0          80.0    60.00          58.00     40.0
# 21       22     62.5    90.0          80.0    60.00          60.00     40.0
# 22       23     72.0    84.0          80.0    62.00          66.00     40.0
# 23       24     75.0    80.0          80.0    68.33          70.00     40.0
# 24       25     79.0    91.0          80.0    76.00          74.00     37.0
# 25       26     77.0    84.0          76.0    68.00          70.00     34.0
#
#     Ampalaya  Sitao  Pechay Tagalog  Squash  Eggplant  Tomato
# 0       80.0   70.0           62.50   40.00    100.00   60.00
# 1       74.0   76.0           60.00   40.00     80.00   60.00
# 2       65.0   77.5           60.00   40.00     60.00   60.00
# 3       60.0   74.0           58.00   40.00     62.00   60.00
# 4       80.0   86.0           60.00   40.00     68.00   60.00
# 5       96.0  100.0           62.00   38.00     91.00   59.00
# 6      100.0  100.0           66.00   38.00    100.00   51.00
# 7       90.0  100.0           66.25   35.00    100.00   60.00
# 8       80.0   94.0           72.00   36.00     78.00   60.00
# 9       95.0  120.0           80.00   40.00     80.00   60.00
# 10     120.0  116.0           70.00   39.00     80.00   60.00
# 11     116.0  112.0           64.00   38.00     80.00   60.00
# 12      92.0   98.0           57.00   40.00     66.00   60.00
# 13      90.0   95.0           59.00   40.00     64.00   60.00
# 14     112.0  100.0           57.00   38.00     60.00   57.00
# 15     100.0   87.5           56.25   37.50     62.50   60.00
# 16     100.0   80.0           60.00   40.00     70.00   60.00
# 17     100.0   80.0           60.00   40.00     72.00   60.00
# 18     116.0   80.0           60.00   40.00     72.00   80.00
# 19     104.0   80.0           58.00   40.00     70.00   80.00
# 20     100.0   80.0           60.00   46.00     59.00   80.00
# 21      95.0   77.5           67.50   50.00     55.00   80.00
# 22      93.0   70.0           68.00   50.00     60.00  100.00
# 23     100.0   80.0           70.00   53.33     76.67  113.33
# 24     100.0   80.0           70.00   50.00     78.00  128.00
# 25     100.0   76.0           62.00   50.00     68.00   98.00

# %%
test
# Out:
#     WeekNum  Cabbage  Carrot  Baguio Beans  Patatas  Pechay Baguio  Chayote  \
# 26       27     81.0    80.0          80.0     68.0           70.0     34.0
# 27       28     80.0    85.0          80.0     75.0           72.5     35.0
# 28       29     80.0    80.0          79.0     74.0           72.0     36.0
# 29       30     72.0    82.0         108.0     76.0           64.0     35.0
#
#     Ampalaya  Sitao  Pechay Tagalog  Squash  Eggplant  Tomato
# 26      98.0   73.0            60.0    50.0      72.0    88.0
# 27     100.0   77.5            60.0    45.0      67.5    97.5
# 28      98.0   79.0            58.0    40.0      62.0    98.0
# 29     100.0  112.0            60.0    40.0      60.0    91.0

# %% [markdown]
# ### RMSE Calculator

# %%
def RMSE(forecast, actual):
  size = len(forecast)
  RMSE = 0
  for i in range(size):
    RMSE += (forecast.iloc[i] - actual.iloc[i])**2
  
  return float(np.sqrt(RMSE/size))

# %% [markdown]
# ### autoARIMA Code

# %%
# Special AUTOARIMA for optimizing RMSE
# Input: The training data and the limitations of the p and q values for ARIMA as n
# Output: The optimal p and q for minimizing RMSE in the model, with the optimal d from ndiffs.
def autoARIMA(training_data, n):
  min_RMSE = max(training_data)
  p_optimal = 0 
  q_optimal = 0
  d = ndiffs(training_data, test = 'kpss', alpha = 0.05)
  for p in range(n + 1):
    for q in range(n + 1):
      # Skip over ARIMA(1, 0), which is the AR model
      if p == 1 and q == 0:
        continue

      # Try-except to determine if the ARIMA model is valid. If valid, fit and determine the RMSE
      try:
        model = ARIMA(training[fixed_query], order=(p,d,q))
        model_fit = model.fit()
        RMSE_train = RMSE(model_fit.predict(0, len(training) - 1), training[fixed_query])
      except:
        continue

      # Compare the RMSE and see if it is minimum. If so, replace previous optimal values.
      print("ARIMA(%d, %d, %d). RMSE = %f"% (p, d, q, RMSE_train))
      if RMSE_train < min_RMSE:
        min_RMSE = RMSE_train
        p_optimal = p
        q_optimal = q

  return [p_optimal, d, q_optimal] # Return calculated values.

# %% [markdown]
# ### Main Function

# %%
def ModelAndForecast(fixed_query):
  # Call the autoARIMA function for the given query.
  p, d, q = autoARIMA(training[fixed_query], 6)
  print("Optimal p: %d\nOptimal d: %d\nOptimal q: %d" % (p, d, q))

  # Create the model for the optmal p d q values and fit
  model = ARIMA(training[fixed_query], order=(p,d,q))
  model_fit = model.fit()

  # Plot the model (in-sample)
  model_plot = model_fit.predict(0, len(training) - 1, typ = 'level')

  # Forecast using the model for the next len(test) (4 in this example) values.
  fc = model_fit.get_forecast(len(test[fixed_query])) 

  # Get the confidence interval at 90%
  conf = fc.conf_int(0.1)

  # Make as pandas series
  fc_series = pd.Series(fc.predicted_mean, index=test.index)
  lower_series = pd.Series(conf["lower "+fixed_query], index=test.index)
  upper_series = pd.Series(conf["upper "+fixed_query], index=test.index)


  # Create the comparison model (AR(1), First-order AutoRegressive Model AKA Random Walk)
  comparison_model = ARIMA(training[fixed_query], order=(1,0,0))
  compared_model_fit = comparison_model.fit()
  compare_fc = compared_model_fit.get_forecast(len(test[fixed_query]))
  conf_2 = compare_fc.conf_int(0.1)
  compare_fc_series = pd.Series(compare_fc.predicted_mean, index=test.index)
  lower_series_2 = pd.Series(conf_2["lower "+fixed_query], index=test.index)
  upper_series_2 = pd.Series(conf_2["upper "+fixed_query], index=test.index)

  # Plot data, model, and forecasts into the diagram.
  plt.figure(figsize=(12,5), dpi=100)
  plt.plot(training[fixed_query], label='training')
  plt.plot(test[fixed_query], label='actual')
  plt.plot(fc_series, label='forecast from model')
  plt.plot(compare_fc_series, label='forecast from AR(1)')
  plt.plot(model_plot, label = 'fit from training')
  plt.fill_between(lower_series.index, lower_series, upper_series, 
                  color='k', alpha=.15)
  plt.fill_between(lower_series_2.index, lower_series_2, upper_series_2, 
                  color='k', alpha=.10)
  plt.title('Forecast vs Actuals of ' + fixed_query)
  plt.legend(loc='lower right', fontsize=8)
  plt.show()

  #Performance Checks
  RMSE_train = RMSE(model_plot, training[fixed_query])
  RMSE_test = RMSE(fc.predicted_mean, test[fixed_query])
  NRMSE_test = RMSE_test/np.average(test[fixed_query])
  print("SELECTED MODEL: ARIMA(%d, %d, %d)" % (p,d,q))
  print("=====================================")
  print("RMSE Training:", RMSE_train)
  print("RMSE Test:", RMSE_test)
  print("Normalized RMSE Test:", NRMSE_test)
  print("=====================================")
  mape = np.mean(np.abs(fc.predicted_mean - test[fixed_query])/np.abs(test[fixed_query]))
  print('MAPE:', str(mape))

  RMSE_test = RMSE(compare_fc.predicted_mean, test[fixed_query])
  NRMSE_test = RMSE_test/np.average(test[fixed_query])
  print("\n\nCOMPARED MODEL: ARIMA(1, 0, 0)")
  print("=====================================")
  print("RMSE Test:", RMSE_test)
  print("Normalized RMSE Test:", NRMSE_test)
  print("=====================================")
  mape = np.mean(np.abs(compare_fc.predicted_mean - test[fixed_query])/np.abs(test[fixed_query]))
  print('MAPE:', str(mape))

# %% [markdown]
# ### ARIMA Modeling (Cabbage)

# %%
# Filter out ConvergenceWarnings. Optional part of code, just to reduce text in the terminal output
warnings.simplefilter('ignore', ConvergenceWarning)

fixed_query = "Cabbage"

ModelAndForecast(fixed_query)
# Out:
# ARIMA(0, 2, 0). RMSE = 26.883576
# ARIMA(0, 2, 1). RMSE = 26.712539
# ARIMA(0, 2, 2). RMSE = 26.710444
# ARIMA(0, 2, 3). RMSE = 26.709773
# ARIMA(0, 2, 4). RMSE = 26.898474
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 2, 5). RMSE = 26.692070
# ARIMA(0, 2, 6). RMSE = nan
# ARIMA(1, 2, 1). RMSE = 26.710445
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:902: RuntimeWarning: Mean of empty slice.
#   params_variance = (residuals[k_params_ma:] ** 2).mean()
# D:\Program Files\Python39\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 2, 2). RMSE = 26.706942
# ARIMA(1, 2, 3). RMSE = 26.710428
# ARIMA(1, 2, 4). RMSE = 26.742384
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 2, 5). RMSE = 26.654976
# ARIMA(2, 2, 0). RMSE = 26.706385
# ARIMA(2, 2, 1). RMSE = 26.706229
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:902: RuntimeWarning: Mean of empty slice.
#   params_variance = (residuals[k_params_ma:] ** 2).mean()
# D:\Program Files\Python39\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 2, 2). RMSE = 26.706792
# ARIMA(2, 2, 3). RMSE = 26.683358
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 2, 4). RMSE = 26.673583
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 2, 5). RMSE = 26.641991
# ARIMA(3, 2, 0). RMSE = 26.706066
# ARIMA(3, 2, 1). RMSE = 26.701863
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:902: RuntimeWarning: Mean of empty slice.
#   params_variance = (residuals[k_params_ma:] ** 2).mean()
# D:\Program Files\Python39\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 2, 2). RMSE = 26.701729
# ARIMA(3, 2, 3). RMSE = 26.656979
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 2, 4). RMSE = 26.670571
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 2, 5). RMSE = 26.653193
# ARIMA(4, 2, 0). RMSE = 26.696612
# ARIMA(4, 2, 1). RMSE = 26.687545
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:902: RuntimeWarning: Mean of empty slice.
#   params_variance = (residuals[k_params_ma:] ** 2).mean()
# D:\Program Files\Python39\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 2, 2). RMSE = 26.696012
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 2, 3). RMSE = 26.654570
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 2, 4). RMSE = 26.656577
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 2, 5). RMSE = 26.639197
# ARIMA(5, 2, 0). RMSE = 26.680415
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:902: RuntimeWarning: Mean of empty slice.
#   params_variance = (residuals[k_params_ma:] ** 2).mean()
# D:\Program Files\Python39\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 2, 1). RMSE = 26.677978
# ARIMA(5, 2, 2). RMSE = 26.691833
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ARIMA(5, 2, 3). RMSE = 26.665460
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 2, 4). RMSE = 26.637957
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 2, 5). RMSE = 26.648523
# ARIMA(6, 2, 0). RMSE = 26.677171
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:902: RuntimeWarning: Mean of empty slice.
#   params_variance = (residuals[k_params_ma:] ** 2).mean()
# D:\Program Files\Python39\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 2, 1). RMSE = 26.676714
# ARIMA(6, 2, 2). RMSE = 26.620608
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 2, 3). RMSE = 26.619425
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 2, 4). RMSE = 26.619107
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 2, 5). RMSE = 26.642759
# Optimal p: 6
# Optimal d: 2
# Optimal q: 4
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:902: RuntimeWarning: Mean of empty slice.
#   params_variance = (residuals[k_params_ma:] ** 2).mean()
# D:\Program Files\Python39\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# SELECTED MODEL: ARIMA(6, 2, 4)
# =====================================
# RMSE Training: 26.619106825934512
# RMSE Test: 5.431893507139071
# Normalized RMSE Test: 0.06941716942030761
# =====================================
# MAPE: 0.05855947128172668
#
#
# COMPARED MODEL: ARIMA(1, 0, 0)
# =====================================
# RMSE Test: 4.035318819857124
# Normalized RMSE Test: 0.05156956958283864
# =====================================
# MAPE: 0.04607852659313655

# %% [markdown]
# ### ARIMA Modeling (Carrot)

# %%
# Filter out ConvergenceWarnings. Optional part of code, just to reduce text in the terminal output
warnings.simplefilter('ignore', ConvergenceWarning)

fixed_query = "Carrot"

ModelAndForecast(fixed_query)
# Out:
# ARIMA(0, 0, 0). RMSE = 19.279285
# ARIMA(0, 0, 1). RMSE = 13.122098
# ARIMA(0, 0, 2). RMSE = 11.591671
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 0, 3). RMSE = 11.135934
# ARIMA(0, 0, 4). RMSE = 11.141629
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 0, 5). RMSE = 11.037575
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 0, 6). RMSE = 11.014652
# ARIMA(1, 0, 1). RMSE = 11.023358
# ARIMA(1, 0, 2). RMSE = 10.995962
# ARIMA(1, 0, 3). RMSE = 10.976459
# ARIMA(1, 0, 4). RMSE = 11.104421
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 0, 5). RMSE = 11.078264
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 0, 6). RMSE = 10.695737
# ARIMA(2, 0, 0). RMSE = 11.193387
# ARIMA(2, 0, 1). RMSE = 11.003600
# ARIMA(2, 0, 2). RMSE = 10.993652
# ARIMA(2, 0, 3). RMSE = 11.049956
# ARIMA(2, 0, 4). RMSE = 10.982456
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 5). RMSE = 10.838160
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 6). RMSE = 10.479697
# ARIMA(3, 0, 0). RMSE = 10.915728
# ARIMA(3, 0, 1). RMSE = 10.915717
# ARIMA(3, 0, 2). RMSE = 10.856641
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 3). RMSE = 10.646422
# ARIMA(3, 0, 4). RMSE = 10.873203
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 5). RMSE = 11.190311
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 6). RMSE = 10.765714
# ARIMA(4, 0, 0). RMSE = 10.915774
# ARIMA(4, 0, 1). RMSE = 10.909005
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 2). RMSE = 10.872311
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 3). RMSE = 10.703069
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ARIMA(4, 0, 4). RMSE = 10.610235
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 5). RMSE = 10.819446
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 6). RMSE = 10.647551
# ARIMA(5, 0, 0). RMSE = 10.934018
# ARIMA(5, 0, 1). RMSE = 10.866096
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 2). RMSE = 10.795802
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 3). RMSE = 10.673375
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ARIMA(5, 0, 4). RMSE = 10.455840
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 5). RMSE = 10.599548
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 6). RMSE = 10.512405
# ARIMA(6, 0, 0). RMSE = 10.839554
# ARIMA(6, 0, 1). RMSE = 10.836992
# ARIMA(6, 0, 2). RMSE = 10.861915
# ARIMA(6, 0, 3). RMSE = 10.612987
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ARIMA(6, 0, 4). RMSE = 10.434978
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 5). RMSE = 10.598576
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 6). RMSE = 10.461247
# Optimal p: 6
# Optimal d: 0
# Optimal q: 4
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# SELECTED MODEL: ARIMA(6, 0, 4)
# =====================================
# RMSE Training: 10.434978312174687
# RMSE Test: 5.851253427482814
# Normalized RMSE Test: 0.0715749654737959
# =====================================
# MAPE: 0.0565149678103476
#
#
# COMPARED MODEL: ARIMA(1, 0, 0)
# =====================================
# RMSE Test: 8.65814903229854
# Normalized RMSE Test: 0.10591007990579254
# =====================================
# MAPE: 0.10081966045945236

# %% [markdown]
# ### ARIMA Modeling (Baguio Beans)

# %%
# Filter out ConvergenceWarnings. Optional part of code, just to reduce text in the terminal output
warnings.simplefilter('ignore', ConvergenceWarning)

fixed_query = "Baguio Beans"

ModelAndForecast(fixed_query)
# Out:
# ARIMA(0, 0, 0). RMSE = 14.095668
# ARIMA(0, 0, 1). RMSE = 12.202943
# ARIMA(0, 0, 2). RMSE = 12.355661
# ARIMA(0, 0, 3). RMSE = 12.046605
# ARIMA(0, 0, 4). RMSE = 12.124042
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 0, 5). RMSE = 12.449465
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 0, 6). RMSE = 12.446722
# ARIMA(1, 0, 1). RMSE = 12.421103
# ARIMA(1, 0, 2). RMSE = 12.220505
# ARIMA(1, 0, 3). RMSE = 12.212356
# ARIMA(1, 0, 4). RMSE = 12.325255
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 0, 5). RMSE = 12.387063
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 0, 6). RMSE = 12.366757
# ARIMA(2, 0, 0). RMSE = 12.615408
# ARIMA(2, 0, 1). RMSE = 12.426758
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 2). RMSE = 12.690560
# ARIMA(2, 0, 3). RMSE = 12.065425
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 4). RMSE = 12.295552
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 5). RMSE = 12.483643
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 6). RMSE = 12.370391
# ARIMA(3, 0, 0). RMSE = 12.448693
# ARIMA(3, 0, 1). RMSE = 12.439987
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 2). RMSE = 12.125399
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 3). RMSE = 12.212955
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 4). RMSE = 12.288188
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 5). RMSE = 12.122164
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 6). RMSE = 12.100862
# ARIMA(4, 0, 0). RMSE = 12.517400
# ARIMA(4, 0, 1). RMSE = 12.641897
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 2). RMSE = 12.244478
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 3). RMSE = 12.456371
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 4). RMSE = 12.364424
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 5). RMSE = 12.115755
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 6). RMSE = 12.340223
# ARIMA(5, 0, 0). RMSE = 12.531566
# ARIMA(5, 0, 1). RMSE = 12.531401
# ARIMA(5, 0, 2). RMSE = 12.601545
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 3). RMSE = 12.406145
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 4). RMSE = 12.236503
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 5). RMSE = 12.147694
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 6). RMSE = 12.298223
# ARIMA(6, 0, 0). RMSE = 12.556426
# ARIMA(6, 0, 1). RMSE = 12.517248
# ARIMA(6, 0, 2). RMSE = 12.607117
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 3). RMSE = 12.344043
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 4). RMSE = 12.341032
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 5). RMSE = 12.262720
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 6). RMSE = 12.183393
# Optimal p: 0
# Optimal d: 0
# Optimal q: 3
# SELECTED MODEL: ARIMA(0, 0, 3)
# =====================================
# RMSE Training: 12.046605137789282
# RMSE Test: 12.363669853623513
# Normalized RMSE Test: 0.14252068995531428
# =====================================
# MAPE: 0.11316839528894446
#
#
# COMPARED MODEL: ARIMA(1, 0, 0)
# =====================================
# RMSE Test: 12.965064042865384
# Normalized RMSE Test: 0.14945318781401018
# =====================================
# MAPE: 0.07430839642084588

# %% [markdown]
# ### ARIMA Modeling (Patatas)

# %%
# Filter out ConvergenceWarnings. Optional part of code, just to reduce text in the terminal output
warnings.simplefilter('ignore', ConvergenceWarning)

fixed_query = "Patatas"

ModelAndForecast(fixed_query)
# Out:
# ARIMA(0, 1, 0). RMSE = 16.395236
# ARIMA(0, 1, 1). RMSE = 16.343466
# ARIMA(0, 1, 2). RMSE = 16.343344
# ARIMA(0, 1, 3). RMSE = 16.289915
# ARIMA(0, 1, 4). RMSE = 16.289619
# ARIMA(0, 1, 5). RMSE = 16.273517
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 1, 6). RMSE = 16.271880
# ARIMA(1, 1, 1). RMSE = 16.333960
# ARIMA(1, 1, 2). RMSE = 16.331337
# ARIMA(1, 1, 3). RMSE = 16.289822
# ARIMA(1, 1, 4). RMSE = 16.285168
# ARIMA(1, 1, 5). RMSE = 16.272919
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 1, 6). RMSE = 16.273317
# ARIMA(2, 1, 0). RMSE = 16.338110
# ARIMA(2, 1, 1). RMSE = 16.332675
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 1, 2). RMSE = 16.321916
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 1, 3). RMSE = 16.271107
# ARIMA(2, 1, 4). RMSE = 16.193331
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 1, 5). RMSE = 16.190859
# ARIMA(2, 1, 6). RMSE = 16.395236
# ARIMA(3, 1, 0). RMSE = 16.311983
# ARIMA(3, 1, 1). RMSE = 16.307904
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 1, 2). RMSE = 16.202065
# ARIMA(3, 1, 3). RMSE = 16.202052
# ARIMA(3, 1, 4). RMSE = 16.192564
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 1, 5). RMSE = 16.192931
# ARIMA(4, 1, 0). RMSE = 16.299313
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 1, 1). RMSE = 16.296140
# ARIMA(4, 1, 2). RMSE = 16.202068
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 1, 3). RMSE = 16.201761
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 1, 4). RMSE = 16.203554
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 1, 5). RMSE = 16.190491
# ARIMA(4, 1, 6). RMSE = 16.395236
# ARIMA(5, 1, 0). RMSE = 16.282713
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 1, 1). RMSE = 16.271215
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 1, 2). RMSE = 16.197564
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ARIMA(5, 1, 3). RMSE = 16.201479
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 1, 4). RMSE = 16.200717
# ARIMA(5, 1, 5). RMSE = 16.395236
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 1, 6). RMSE = 16.395236
# ARIMA(6, 1, 0). RMSE = 16.235960
# ARIMA(6, 1, 1). RMSE = 16.219073
# ARIMA(6, 1, 2). RMSE = 16.194526
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 1, 3). RMSE = 16.189533
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 1, 4). RMSE = 16.147794
# ARIMA(6, 1, 5). RMSE = 16.395236
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 1, 6). RMSE = 16.395236
# Optimal p: 6
# Optimal d: 1
# Optimal q: 4
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# SELECTED MODEL: ARIMA(6, 1, 4)
# =====================================
# RMSE Training: 16.14779426782473
# RMSE Test: 4.864475862694828
# Normalized RMSE Test: 0.06640922679446865
# =====================================
# MAPE: 0.05490901664168832
#
#
# COMPARED MODEL: ARIMA(1, 0, 0)
# =====================================
# RMSE Test: 4.619061261288171
# Normalized RMSE Test: 0.06305885680939483
# =====================================
# MAPE: 0.05530280678044695

# %% [markdown]
# ### ARIMA Modeling (Pechay Baguio)

# %%
# Filter out ConvergenceWarnings. Optional part of code, just to reduce text in the terminal output
warnings.simplefilter('ignore', ConvergenceWarning)

fixed_query = "Pechay Baguio"

ModelAndForecast(fixed_query)
# Out:
# ARIMA(0, 0, 0). RMSE = 5.133940
# ARIMA(0, 0, 1). RMSE = 4.101034
# ARIMA(0, 0, 2). RMSE = 3.662798
# ARIMA(0, 0, 3). RMSE = 3.656146
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 0, 4). RMSE = 3.483851
# ARIMA(0, 0, 5). RMSE = 3.483088
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 0, 6). RMSE = 3.490999
# ARIMA(1, 0, 1). RMSE = 3.605346
# ARIMA(1, 0, 2). RMSE = 3.612203
# ARIMA(1, 0, 3). RMSE = 3.634686
# ARIMA(1, 0, 4). RMSE = 3.483040
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 0, 5). RMSE = 3.468161
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 0, 6). RMSE = 3.483736
# ARIMA(2, 0, 0). RMSE = 3.611390
# ARIMA(2, 0, 1). RMSE = 3.558837
# ARIMA(2, 0, 2). RMSE = 3.369792
# ARIMA(2, 0, 3). RMSE = 3.356270
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 4). RMSE = 3.428472
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 5). RMSE = 3.403219
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 6). RMSE = 3.405949
# ARIMA(3, 0, 0). RMSE = 3.618443
# ARIMA(3, 0, 1). RMSE = 3.437102
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 2). RMSE = 3.436648
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 3). RMSE = 3.368430
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 4). RMSE = 3.391188
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 5). RMSE = 3.371823
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 6). RMSE = 3.402295
# ARIMA(4, 0, 0). RMSE = 3.603943
# ARIMA(4, 0, 1). RMSE = 3.378626
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 2). RMSE = 3.415626
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 3). RMSE = 3.342946
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 4). RMSE = 3.343629
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 5). RMSE = 3.326122
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 6). RMSE = 3.307939
# ARIMA(5, 0, 0). RMSE = 3.561455
# ARIMA(5, 0, 1). RMSE = 3.358452
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 2). RMSE = 3.300889
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 3). RMSE = 3.358295
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 4). RMSE = 3.223983
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 5). RMSE = 3.253403
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 6). RMSE = 3.217662
# ARIMA(6, 0, 0). RMSE = 3.530115
# ARIMA(6, 0, 1). RMSE = 3.354647
# ARIMA(6, 0, 2). RMSE = 3.300677
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 3). RMSE = 3.197828
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 4). RMSE = 3.232509
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 5). RMSE = 3.237731
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 6). RMSE = 3.252320
# Optimal p: 6
# Optimal d: 0
# Optimal q: 3
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# SELECTED MODEL: ARIMA(6, 0, 3)
# =====================================
# RMSE Training: 3.1978282001803615
# RMSE Test: 3.5600353736098675
# Normalized RMSE Test: 0.05113156730498912
# =====================================
# MAPE: 0.041018977531869893
#
#
# COMPARED MODEL: ARIMA(1, 0, 0)
# =====================================
# RMSE Test: 3.848228013852162
# Normalized RMSE Test: 0.05527077937310107
# =====================================
# MAPE: 0.04828133043118381

# %% [markdown]
# ### ARIMA Modeling (Chayote)

# %%
# Filter out ConvergenceWarnings. Optional part of code, just to reduce text in the terminal output
warnings.simplefilter('ignore', ConvergenceWarning)

fixed_query = "Chayote"

ModelAndForecast(fixed_query)
# Out:
# ARIMA(0, 0, 0). RMSE = 4.124720
# ARIMA(0, 0, 1). RMSE = 2.616399
# ARIMA(0, 0, 2). RMSE = 2.438942
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 0, 3). RMSE = 2.397534
# ARIMA(0, 0, 4). RMSE = 2.262427
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 0, 5). RMSE = 2.125945
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 0, 6). RMSE = 2.108923
# ARIMA(1, 0, 1). RMSE = 2.359664
# ARIMA(1, 0, 2). RMSE = 2.304278
# ARIMA(1, 0, 3). RMSE = 2.279282
# ARIMA(1, 0, 4). RMSE = 2.141548
# ARIMA(1, 0, 5). RMSE = 2.112821
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 0, 6). RMSE = 2.101687
# ARIMA(2, 0, 0). RMSE = 2.632546
# ARIMA(2, 0, 1). RMSE = 2.308276
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 2). RMSE = 2.297693
# ARIMA(2, 0, 3). RMSE = 2.182187
# ARIMA(2, 0, 4). RMSE = 2.118114
# ARIMA(2, 0, 5). RMSE = 2.098660
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 6). RMSE = 2.115557
# ARIMA(3, 0, 0). RMSE = 2.566029
# ARIMA(3, 0, 1). RMSE = 2.280962
# ARIMA(3, 0, 2). RMSE = 2.259946
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 3). RMSE = 2.120527
# ARIMA(3, 0, 4). RMSE = 2.116215
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 5). RMSE = 2.114485
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 6). RMSE = 2.114468
# ARIMA(4, 0, 0). RMSE = 2.308670
# ARIMA(4, 0, 1). RMSE = 2.267992
# ARIMA(4, 0, 2). RMSE = 2.187316
# ARIMA(4, 0, 3). RMSE = 2.114636
# ARIMA(4, 0, 4). RMSE = 2.074746
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 5). RMSE = 2.114267
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 6). RMSE = 2.113546
# ARIMA(5, 0, 0). RMSE = 2.308745
# ARIMA(5, 0, 1). RMSE = 2.203350
# ARIMA(5, 0, 2). RMSE = 2.192893
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 3). RMSE = 2.114071
# ARIMA(5, 0, 4). RMSE = 2.077694
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 5). RMSE = 2.091447
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 6). RMSE = 2.117975
# ARIMA(6, 0, 0). RMSE = 2.301692
# ARIMA(6, 0, 1). RMSE = 2.181366
# ARIMA(6, 0, 2). RMSE = 2.172054
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 3). RMSE = 2.113865
# ARIMA(6, 0, 4). RMSE = 2.075895
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 5). RMSE = 2.106271
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 6). RMSE = 2.092985
# Optimal p: 4
# Optimal d: 0
# Optimal q: 4
# SELECTED MODEL: ARIMA(4, 0, 4)
# =====================================
# RMSE Training: 2.0747464350658444
# RMSE Test: 1.7513106045679003
# Normalized RMSE Test: 0.050037445844797156
# =====================================
# MAPE: 0.04565380751718725
#
#
# COMPARED MODEL: ARIMA(1, 0, 0)
# =====================================
# RMSE Test: 2.051335531643605
# Normalized RMSE Test: 0.058609586618388713
# =====================================
# MAPE: 0.0549012993476468

# %% [markdown]
# ### ARIMA Modeling (Ampalaya)

# %%
# Filter out ConvergenceWarnings. Optional part of code, just to reduce text in the terminal output
warnings.simplefilter('ignore', ConvergenceWarning)

fixed_query = "Ampalaya"

ModelAndForecast(fixed_query)
# Out:
# ARIMA(0, 1, 0). RMSE = 19.593955
# ARIMA(0, 1, 1). RMSE = 19.479362
# ARIMA(0, 1, 2). RMSE = 18.794483
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 1, 3). RMSE = 18.110185
# ARIMA(0, 1, 4). RMSE = 17.869945
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 1, 5). RMSE = 17.702792
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 1, 6). RMSE = 17.700747
# ARIMA(1, 1, 1). RMSE = 19.216424
# ARIMA(1, 1, 2). RMSE = 18.751010
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 1, 3). RMSE = 18.045212
# ARIMA(1, 1, 4). RMSE = 17.746937
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 1, 5). RMSE = 17.702926
# ARIMA(1, 1, 6). RMSE = 17.705913
# ARIMA(2, 1, 0). RMSE = 18.491113
# ARIMA(2, 1, 1). RMSE = 18.256297
# ARIMA(2, 1, 2). RMSE = 18.135420
# ARIMA(2, 1, 3). RMSE = 18.135086
# ARIMA(2, 1, 4). RMSE = 17.650033
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 1, 5). RMSE = 17.682751
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 1, 6). RMSE = 17.592835
# ARIMA(3, 1, 0). RMSE = 18.093923
# ARIMA(3, 1, 1). RMSE = 18.036126
# ARIMA(3, 1, 2). RMSE = 18.033063
# ARIMA(3, 1, 3). RMSE = 17.779265
# ARIMA(3, 1, 4). RMSE = 17.596901
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 1, 5). RMSE = 17.590773
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 1, 6). RMSE = 17.590283
# ARIMA(4, 1, 0). RMSE = 18.040912
# ARIMA(4, 1, 1). RMSE = 18.034089
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 1, 2). RMSE = 18.012546
# ARIMA(4, 1, 3). RMSE = 17.708501
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 1, 4). RMSE = 17.594459
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 1, 5). RMSE = 17.600060
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 1, 6). RMSE = 17.596650
# ARIMA(5, 1, 0). RMSE = 18.035769
# ARIMA(5, 1, 1). RMSE = 18.033052
# ARIMA(5, 1, 2). RMSE = 18.016035
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 1, 3). RMSE = 17.714269
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 1, 4). RMSE = 17.596119
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 1, 5). RMSE = 17.588513
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 1, 6). RMSE = 17.590504
# ARIMA(6, 1, 0). RMSE = 18.005242
# ARIMA(6, 1, 1). RMSE = 17.937937
# ARIMA(6, 1, 2). RMSE = 17.908457
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 1, 3). RMSE = 17.701513
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 1, 4). RMSE = 17.598615
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 1, 5). RMSE = 17.593241
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 1, 6). RMSE = 17.529443
# Optimal p: 6
# Optimal d: 1
# Optimal q: 6
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# SELECTED MODEL: ARIMA(6, 1, 6)
# =====================================
# RMSE Training: 17.52944311936795
# RMSE Test: 8.669699189075349
# Normalized RMSE Test: 0.08757271908156918
# =====================================
# MAPE: 0.07040384930556128
#
#
# COMPARED MODEL: ARIMA(1, 0, 0)
# =====================================
# RMSE Test: 3.2544875678156466
# Normalized RMSE Test: 0.03287361179611764
# =====================================
# MAPE: 0.027453990475988725

# %% [markdown]
# ### ARIMA Modeling (Sitao)

# %%
# Filter out ConvergenceWarnings. Optional part of code, just to reduce text in the terminal output
warnings.simplefilter('ignore', ConvergenceWarning)

fixed_query = "Sitao"

ModelAndForecast(fixed_query)
# Out:
# ARIMA(0, 0, 0). RMSE = 13.797524
# ARIMA(0, 0, 1). RMSE = 10.207617
# ARIMA(0, 0, 2). RMSE = 8.825623
# ARIMA(0, 0, 3). RMSE = 8.652103
# ARIMA(0, 0, 4). RMSE = 8.650552
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 0, 5). RMSE = 7.596689
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 0, 6). RMSE = 7.457632
# ARIMA(1, 0, 1). RMSE = 8.290170
# ARIMA(1, 0, 2). RMSE = 8.281774
# ARIMA(1, 0, 3). RMSE = 8.213940
# ARIMA(1, 0, 4). RMSE = 7.478468
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 0, 5). RMSE = 7.238224
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 0, 6). RMSE = 7.220927
# ARIMA(2, 0, 0). RMSE = 8.290648
# ARIMA(2, 0, 1). RMSE = 8.286816
# ARIMA(2, 0, 2). RMSE = 8.290272
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 3). RMSE = 7.666589
# ARIMA(2, 0, 4). RMSE = 7.371150
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 5). RMSE = 7.224131
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 6). RMSE = 7.559484
# ARIMA(3, 0, 0). RMSE = 8.273955
# ARIMA(3, 0, 1). RMSE = 8.273953
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 2). RMSE = 7.971422
# ARIMA(3, 0, 3). RMSE = 7.646998
# ARIMA(3, 0, 4). RMSE = 7.115077
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 5). RMSE = 7.223697
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 6). RMSE = 7.598809
# ARIMA(4, 0, 0). RMSE = 8.275368
# ARIMA(4, 0, 1). RMSE = 8.235684
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 2). RMSE = 7.862981
# ARIMA(4, 0, 3). RMSE = 6.875306
# ARIMA(4, 0, 4). RMSE = 6.708094
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 5). RMSE = 6.638125
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 6). RMSE = 7.596841
# ARIMA(5, 0, 0). RMSE = 7.796478
# ARIMA(5, 0, 1). RMSE = 6.967944
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 2). RMSE = 6.986896
# ARIMA(5, 0, 3). RMSE = 6.633077
# ARIMA(5, 0, 4). RMSE = 6.631933
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 5). RMSE = 6.741132
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 6). RMSE = 7.413770
# ARIMA(6, 0, 0). RMSE = 6.824558
# ARIMA(6, 0, 1). RMSE = 6.821161
# ARIMA(6, 0, 2). RMSE = 6.764112
# ARIMA(6, 0, 3). RMSE = 6.723082
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 4). RMSE = 6.621857
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 5). RMSE = 6.494900
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 6). RMSE = 6.473330
# Optimal p: 6
# Optimal d: 0
# Optimal q: 6
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# SELECTED MODEL: ARIMA(6, 0, 6)
# =====================================
# RMSE Training: 6.473329505432115
# RMSE Test: 12.169649774283835
# Normalized RMSE Test: 0.14254348198282676
# =====================================
# MAPE: 0.09507914339308392
#
#
# COMPARED MODEL: ARIMA(1, 0, 0)
# =====================================
# RMSE Test: 15.96364755492669
# Normalized RMSE Test: 0.18698269464042974
# =====================================
# MAPE: 0.09130815985258421

# %% [markdown]
# ### ARIMA Modeling (Pechay Tagalog)

# %%
# Filter out ConvergenceWarnings. Optional part of code, just to reduce text in the terminal output
warnings.simplefilter('ignore', ConvergenceWarning)

fixed_query = "Pechay Tagalog"

ModelAndForecast(fixed_query)
# Out:
# ARIMA(0, 0, 0). RMSE = 5.648218
# ARIMA(0, 0, 1). RMSE = 4.087686
# ARIMA(0, 0, 2). RMSE = 3.774315
# ARIMA(0, 0, 3). RMSE = 3.671406
# ARIMA(0, 0, 4). RMSE = 3.647658
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 0, 5). RMSE = 3.591700
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 0, 6). RMSE = 3.193053
# ARIMA(1, 0, 1). RMSE = 3.767500
# ARIMA(1, 0, 2). RMSE = 3.715811
# ARIMA(1, 0, 3). RMSE = 3.622171
# ARIMA(1, 0, 4). RMSE = 3.465207
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 0, 5). RMSE = 3.463202
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 0, 6). RMSE = 3.157872
# ARIMA(2, 0, 0). RMSE = 3.662820
# ARIMA(2, 0, 1). RMSE = 3.290072
# ARIMA(2, 0, 2). RMSE = 3.288961
# ARIMA(2, 0, 3). RMSE = 3.283806
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 4). RMSE = 3.239078
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 5). RMSE = 3.220376
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 6). RMSE = 3.149784
# ARIMA(3, 0, 0). RMSE = 3.583886
# ARIMA(3, 0, 1). RMSE = 3.289130
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 2). RMSE = 3.222010
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 3). RMSE = 3.217830
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 4). RMSE = 3.217876
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 5). RMSE = 3.129907
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 6). RMSE = 3.071386
# ARIMA(4, 0, 0). RMSE = 3.518059
# ARIMA(4, 0, 1). RMSE = 3.478500
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 2). RMSE = 3.217755
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 3). RMSE = 3.208027
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 4). RMSE = 3.183795
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 5). RMSE = 3.028136
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 6). RMSE = 3.069096
# ARIMA(5, 0, 0). RMSE = 3.486770
# ARIMA(5, 0, 1). RMSE = 3.278065
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 2). RMSE = 3.217411
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 3). RMSE = 3.180289
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 4). RMSE = 3.134090
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 5). RMSE = 3.113149
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 6). RMSE = 3.054362
# ARIMA(6, 0, 0). RMSE = 3.405044
# ARIMA(6, 0, 1). RMSE = 3.334475
# ARIMA(6, 0, 2). RMSE = 3.176605
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 3). RMSE = 3.104559
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 4). RMSE = 3.083403
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 5). RMSE = 3.074596
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 6). RMSE = 2.986611
# Optimal p: 6
# Optimal d: 0
# Optimal q: 6
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# SELECTED MODEL: ARIMA(6, 0, 6)
# =====================================
# RMSE Training: 2.986611053472471
# RMSE Test: 2.097024391898623
# Normalized RMSE Test: 0.035244107426867614
# =====================================
# MAPE: 0.03165610895352194
#
#
# COMPARED MODEL: ARIMA(1, 0, 0)
# =====================================
# RMSE Test: 3.285335275807259
# Normalized RMSE Test: 0.055215718921130405
# =====================================
# MAPE: 0.0530953330517759

# %% [markdown]
# ### ARIMA Modeling (Squash)

# %%
# Filter out ConvergenceWarnings. Optional part of code, just to reduce text in the terminal output
warnings.simplefilter('ignore', ConvergenceWarning)

fixed_query = "Squash"

ModelAndForecast(fixed_query)
# Out:
# ARIMA(0, 1, 0). RMSE = 8.135104
# ARIMA(0, 1, 1). RMSE = 8.133330
# ARIMA(0, 1, 2). RMSE = 8.129687
# ARIMA(0, 1, 3). RMSE = 8.111552
# ARIMA(0, 1, 4). RMSE = 8.108955
# ARIMA(0, 1, 5). RMSE = 8.108965
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 1, 6). RMSE = 8.102018
# ARIMA(1, 1, 1). RMSE = 8.111152
# ARIMA(1, 1, 2). RMSE = 8.109771
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 1, 3). RMSE = 8.108064
# ARIMA(1, 1, 4). RMSE = 8.107430
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 1, 5). RMSE = 8.108584
# ARIMA(1, 1, 6). RMSE = 8.101349
# ARIMA(2, 1, 0). RMSE = 8.131771
# ARIMA(2, 1, 1). RMSE = 8.109523
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 1, 2). RMSE = 8.110694
# ARIMA(2, 1, 3). RMSE = 8.107677
# ARIMA(2, 1, 4). RMSE = 8.107425
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 1, 5). RMSE = 8.105598
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 1, 6). RMSE = 8.070224
# ARIMA(3, 1, 0). RMSE = 8.123756
# ARIMA(3, 1, 1). RMSE = 8.108559
# ARIMA(3, 1, 2). RMSE = 8.108213
# ARIMA(3, 1, 3). RMSE = 8.090020
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 1, 4). RMSE = 8.081719
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 1, 5). RMSE = 8.081224
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 1, 6). RMSE = 8.070293
# ARIMA(4, 1, 0). RMSE = 8.122611
# ARIMA(4, 1, 1). RMSE = 8.108209
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 1, 2). RMSE = 8.107953
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 1, 3). RMSE = 8.089966
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 1, 4). RMSE = 8.088552
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 1, 5). RMSE = 8.088028
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 1, 6). RMSE = 8.071038
# ARIMA(5, 1, 0). RMSE = 8.122347
# ARIMA(5, 1, 1). RMSE = 8.107311
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 1, 2). RMSE = 8.107139
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 1, 3). RMSE = 8.089767
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 1, 4). RMSE = 8.087837
# ARIMA(5, 1, 5). RMSE = 8.135104
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 1, 6). RMSE = 8.069118
# ARIMA(6, 1, 0). RMSE = 8.103746
# ARIMA(6, 1, 1). RMSE = 8.093957
# ARIMA(6, 1, 2). RMSE = 8.093968
# ARIMA(6, 1, 3). RMSE = 8.079513
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 1, 4). RMSE = 8.078939
# ARIMA(6, 1, 5). RMSE = 8.135104
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 1, 6). RMSE = 8.135104
# Optimal p: 5
# Optimal d: 1
# Optimal q: 6
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# SELECTED MODEL: ARIMA(5, 1, 6)
# =====================================
# RMSE Training: 8.069118003123927
# RMSE Test: 4.943099062349716
# Normalized RMSE Test: 0.11298512142513636
# =====================================
# MAPE: 0.09813651650027491
#
#
# COMPARED MODEL: ARIMA(1, 0, 0)
# =====================================
# RMSE Test: 6.012719091387755
# Normalized RMSE Test: 0.13743357923172012
# =====================================
# MAPE: 0.12490166054649068

# %% [markdown]
# ### ARIMA Modeling (Eggplant)

# %%
# Filter out ConvergenceWarnings. Optional part of code, just to reduce text in the terminal output
warnings.simplefilter('ignore', ConvergenceWarning)

fixed_query = "Eggplant"

ModelAndForecast(fixed_query)
# Out:
# ARIMA(0, 0, 0). RMSE = 12.741507
# ARIMA(0, 0, 1). RMSE = 10.098155
# ARIMA(0, 0, 2). RMSE = 8.580664
# ARIMA(0, 0, 3). RMSE = 8.600950
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 0, 4). RMSE = 8.587866
# ARIMA(0, 0, 5). RMSE = 8.534883
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 0, 6). RMSE = 8.534699
# ARIMA(1, 0, 1). RMSE = 9.605276
# ARIMA(1, 0, 2). RMSE = 8.610777
# ARIMA(1, 0, 3). RMSE = 8.600302
# ARIMA(1, 0, 4). RMSE = 8.542207
# ARIMA(1, 0, 5). RMSE = 8.538229
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 0, 6). RMSE = 8.448302
# ARIMA(2, 0, 0). RMSE = 9.169823
# ARIMA(2, 0, 1). RMSE = 9.165521
# ARIMA(2, 0, 2). RMSE = 8.566986
# ARIMA(2, 0, 3). RMSE = 8.530194
# ARIMA(2, 0, 4). RMSE = 8.190705
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 5). RMSE = 8.196132
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 6). RMSE = 8.346839
# ARIMA(3, 0, 0). RMSE = 9.158913
# ARIMA(3, 0, 1). RMSE = 8.961246
# ARIMA(3, 0, 2). RMSE = 8.472657
# ARIMA(3, 0, 3). RMSE = 8.452960
# ARIMA(3, 0, 4). RMSE = 8.299658
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 5). RMSE = 8.152023
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 6). RMSE = 8.379652
# ARIMA(4, 0, 0). RMSE = 8.614231
# ARIMA(4, 0, 1). RMSE = 8.441655
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 2). RMSE = 8.440379
# ARIMA(4, 0, 3). RMSE = 8.358037
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ARIMA(4, 0, 4). RMSE = 8.208564
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 5). RMSE = 8.229738
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 6). RMSE = 8.221288
# ARIMA(5, 0, 0). RMSE = 8.546630
# ARIMA(5, 0, 1). RMSE = 8.442764
# ARIMA(5, 0, 2). RMSE = 8.398737
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 3). RMSE = 8.408658
# ARIMA(5, 0, 4). RMSE = 8.089355
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 5). RMSE = 8.219554
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 6). RMSE = 8.204841
# ARIMA(6, 0, 0). RMSE = 8.426376
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ARIMA(6, 0, 1). RMSE = 8.394003
# ARIMA(6, 0, 2). RMSE = 8.164380
# ARIMA(6, 0, 3). RMSE = 8.361614
# ARIMA(6, 0, 4). RMSE = 8.131371
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 5). RMSE = 8.139658
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 6). RMSE = 8.186974
# Optimal p: 5
# Optimal d: 0
# Optimal q: 4
# SELECTED MODEL: ARIMA(5, 0, 4)
# =====================================
# RMSE Training: 8.089355390402103
# RMSE Test: 13.358301280834898
# Normalized RMSE Test: 0.20433348039518007
# =====================================
# MAPE: 0.1879675750944558
#
#
# COMPARED MODEL: ARIMA(1, 0, 0)
# =====================================
# RMSE Test: 8.968034092022323
# Normalized RMSE Test: 0.1371783417517755
# =====================================
# MAPE: 0.12196126341477641

# %% [markdown]
# ### ARIMA Modeling (Tomato)

# %%
# Filter out ConvergenceWarnings. Optional part of code, just to reduce text in the terminal output
warnings.simplefilter('ignore', ConvergenceWarning)

fixed_query = "Tomato"

ModelAndForecast(fixed_query)
# Out:
# ARIMA(0, 1, 0). RMSE = 15.008841
# ARIMA(0, 1, 1). RMSE = 15.005880
# ARIMA(0, 1, 2). RMSE = 14.992746
# ARIMA(0, 1, 3). RMSE = 14.498166
# ARIMA(0, 1, 4). RMSE = 14.103070
# ARIMA(0, 1, 5). RMSE = 14.002248
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 1, 6). RMSE = 14.017453
# ARIMA(1, 1, 1). RMSE = 14.989586
# ARIMA(1, 1, 2). RMSE = 14.975103
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 1, 3). RMSE = 14.456610
# ARIMA(1, 1, 4). RMSE = 14.150863
# ARIMA(1, 1, 5). RMSE = 14.076794
# ARIMA(1, 1, 6). RMSE = 15.008841
# ARIMA(2, 1, 0). RMSE = 14.993996
# ARIMA(2, 1, 1). RMSE = 14.950623
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 1, 2). RMSE = 14.592398
# ARIMA(2, 1, 3). RMSE = 14.396722
# ARIMA(2, 1, 4). RMSE = 13.912460
# ARIMA(2, 1, 5). RMSE = 13.849949
# ARIMA(2, 1, 6). RMSE = 15.008841
# ARIMA(3, 1, 0). RMSE = 14.627727
# ARIMA(3, 1, 1). RMSE = 14.509230
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 1, 2). RMSE = 14.420888
# ARIMA(3, 1, 3). RMSE = 14.294191
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 1, 4). RMSE = 14.275358
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 1, 5). RMSE = 13.884019
# ARIMA(3, 1, 6). RMSE = 15.008840
# ARIMA(4, 1, 0). RMSE = 14.455683
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 1, 1). RMSE = 14.286480
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 1, 2). RMSE = 13.969197
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 1, 3). RMSE = 13.844285
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 1, 4). RMSE = 13.846957
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 1, 5). RMSE = 13.785698
# ARIMA(4, 1, 6). RMSE = 15.008840
# ARIMA(5, 1, 0). RMSE = 14.310303
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ARIMA(5, 1, 1). RMSE = 14.224018
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 1, 2). RMSE = 13.864810
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 1, 3). RMSE = 13.848356
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 1, 4). RMSE = 13.566666
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 1, 6). RMSE = 15.008840
# ARIMA(6, 1, 0). RMSE = 14.054639
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ARIMA(6, 1, 1). RMSE = 13.957494
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ARIMA(6, 1, 2). RMSE = 13.407550
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ARIMA(6, 1, 3). RMSE = 13.861569
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 1, 4). RMSE = 13.361172
# ARIMA(6, 1, 5). RMSE = 15.008840
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Optimal p: 6
# Optimal d: 1
# Optimal q: 4
# SELECTED MODEL: ARIMA(6, 1, 4)
# =====================================
# RMSE Training: 13.36117194548866
# RMSE Test: 21.895515013343527
# Normalized RMSE Test: 0.23386397878070522
# =====================================
# MAPE: 0.21496980507973484
#
#
# COMPARED MODEL: ARIMA(1, 0, 0)
# =====================================
# RMSE Test: 5.995193556647808
# Normalized RMSE Test: 0.06403411008435576
# =====================================
# MAPE: 0.060533660206376246

# %% [markdown]
# ### ARIMA Modeling (With Query)

# %%
# Filter out ConvergenceWarnings. Optional part of code, just to reduce text in the terminal output
warnings.simplefilter('ignore', ConvergenceWarning)

# Get user input. User input should be limited to only the vegetables available in the data set.
query = str.split(input(), " ")
fixed_query = ""

# Fix query into something readable by the program. (Capital first letter, lowercase every other letter per word)
for word in query:
  fixed_query += word[0].upper() + word[1:].lower() + " "
fixed_query = fixed_query[:-1]

ModelAndForecast(fixed_query)
# Out:
# Carrot
# ARIMA(0, 0, 0). RMSE = 19.279285
# ARIMA(0, 0, 1). RMSE = 13.122098
# ARIMA(0, 0, 2). RMSE = 11.591671
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 0, 3). RMSE = 11.135934
# ARIMA(0, 0, 4). RMSE = 11.141629
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 0, 5). RMSE = 11.037575
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(0, 0, 6). RMSE = 11.014652
# ARIMA(1, 0, 1). RMSE = 11.023358
# ARIMA(1, 0, 2). RMSE = 10.995962
# ARIMA(1, 0, 3). RMSE = 10.976459
# ARIMA(1, 0, 4). RMSE = 11.104421
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 0, 5). RMSE = 11.078264
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(1, 0, 6). RMSE = 10.695737
# ARIMA(2, 0, 0). RMSE = 11.193387
# ARIMA(2, 0, 1). RMSE = 11.003600
# ARIMA(2, 0, 2). RMSE = 10.993652
# ARIMA(2, 0, 3). RMSE = 11.049956
# ARIMA(2, 0, 4). RMSE = 10.982456
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 5). RMSE = 10.838160
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(2, 0, 6). RMSE = 10.479697
# ARIMA(3, 0, 0). RMSE = 10.915728
# ARIMA(3, 0, 1). RMSE = 10.915717
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 2). RMSE = 10.856641
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 3). RMSE = 10.646422
# ARIMA(3, 0, 4). RMSE = 10.873203
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 5). RMSE = 11.190311
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(3, 0, 6). RMSE = 10.765714
# ARIMA(4, 0, 0). RMSE = 10.915774
# ARIMA(4, 0, 1). RMSE = 10.909005
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 2). RMSE = 10.872311
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 3). RMSE = 10.703069
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ARIMA(4, 0, 4). RMSE = 10.610235
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 5). RMSE = 10.819446
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(4, 0, 6). RMSE = 10.647551
# ARIMA(5, 0, 0). RMSE = 10.934018
# ARIMA(5, 0, 1). RMSE = 10.866096
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 2). RMSE = 10.795802
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 3). RMSE = 10.673375
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ARIMA(5, 0, 4). RMSE = 10.455840
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 5). RMSE = 10.599548
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(5, 0, 6). RMSE = 10.512405
# ARIMA(6, 0, 0). RMSE = 10.839554
# ARIMA(6, 0, 1). RMSE = 10.836992
# ARIMA(6, 0, 2). RMSE = 10.861915
# ARIMA(6, 0, 3). RMSE = 10.612987
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ARIMA(6, 0, 4). RMSE = 10.434978
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 5). RMSE = 10.598576
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ARIMA(6, 0, 6). RMSE = 10.461247
# Optimal p: 6
# Optimal d: 0
# Optimal q: 4
# D:\Program Files\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# SELECTED MODEL: ARIMA(6, 0, 4)
# =====================================
# RMSE Training: 10.434978312174687
# RMSE Test: 5.851253427482814
# Normalized RMSE Test: 0.0715749654737959
# =====================================
# MAPE: 0.0565149678103476
#
#
# COMPARED MODEL: ARIMA(1, 0, 0)
# =====================================
# RMSE Test: 8.65814903229854
# Normalized RMSE Test: 0.10591007990579254
# =====================================
# MAPE: 0.10081966045945236
